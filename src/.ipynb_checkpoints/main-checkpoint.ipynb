# %%
import matplotlib.pyplot as plt
import numpy as np
import re 
import tweepy 
from tweepy import OAuthHandler 
from textblob import TextBlob 
  
def get_file_contents(filename):

    try:
        with open(filename, 'r') as f:
            return f.read().strip()
    except FileNotFoundError:
        print("'%s' file not found" % filename)

class TwitterClient(object): 

    def __init__(self): 

        consumer_key = get_file_contents("consumerKey.txt")
        consumer_secret = get_file_contents("consumerSecret.txt")
        access_token = get_file_contents("accessToken.txt")
        access_token_secret = get_file_contents("accessTokenSecret.txt")
  
        try: 
            self.auth = OAuthHandler(consumer_key, consumer_secret) 
            self.auth.set_access_token(access_token, access_token_secret) 
            self.api = tweepy.API(self.auth) 
        except: 
            print("Error: Authentication Failed") 
  
    def clean_tweet(self, tweet): 
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) | (\w+:\/\/\S+)", " ", tweet).split()) 
  
    def get_tweet_sentiment(self, tweet): 
        analysis = TextBlob(self.clean_tweet(tweet)) 
        if analysis.sentiment.polarity > 0: 
            return 'positive', analysis.sentiment.polarity
        elif analysis.sentiment.polarity == 0: 
            return 'neutral', analysis.sentiment.polarity
        else: 
            return 'negative', analysis.sentiment.polarity
  
    def get_tweets(self, user_id, count = 10000): 
        tweets = [] 
        tweet_dates = []  
        fetched_tweets = []
        try: 
            for status in tweepy.Cursor(self.api.user_timeline, screen_name=user_id, tweet_mode="extended").items():
                fetched_tweets.append(status)
            

            for tweet in fetched_tweets: 
                parsed_tweet = {} 
                parsed_tweet['text'] = tweet.full_text
                parsed_tweet['sentiment'], parsed_tweet['polarity'] = self.get_tweet_sentiment(tweet.full_text) 
                parsed_tweet['date'] = tweet.created_at
  
                if tweet.retweet_count > 0: 
                    if parsed_tweet not in tweets: 
                        tweets.append(parsed_tweet) 
                else: 
                    tweets.append(parsed_tweet) 
  
            return tweets
  
        except tweepy.TweepError as e: 
            print("Error : " + str(e))

def main(): 
    api = TwitterClient() 
    
    tweets = api.get_tweets(user_id = 'elonmusk', count = 10000) 
    tweet_dates = []
    tweet_polarity_points = []
    print("Tweet count: ", len(tweets))
    for tweet in tweets:
        print("Tweet: ", tweet, "  - Date: ", str(tweet['date']))
        tweet_dates.append(tweet['date'])
        tweet_polarity_points.append(tweet['polarity'])
    
    scatter_plot = plt.figure(figsize=(14, 8), dpi=80)
    plt.scatter(tweet_dates, tweet_polarity_points, s =.25, c = 'green')
    scatter_plot.show()
    scatter_plot.savefig('elon.png', dpi='figure')
    
    
    positive_tweet_sum = sum(status['sentiment'] == "positive" for status in tweets)
    neutral_tweet_sum = sum(status['sentiment'] == "neutral" for status in tweets)
    negative_tweet_sum = sum(status['sentiment'] == "negative" for status in tweets)
    
    
    print("Positive tweets: ", positive_tweet_sum, "(", ((positive_tweet_sum/len(tweets))*100), "%)")
    print("Neutral tweets: ", neutral_tweet_sum, "(", ((neutral_tweet_sum/len(tweets))*100), "%)" )
    print("Negative tweets: ", negative_tweet_sum, "(", ((negative_tweet_sum/len(tweets))*100), "%)")
if __name__ == "__main__": 
    # calling main function 
    main()
# Out:
# Tweet count:  3245
# Tweet:  {'text': '@s3xynews @patfan198010 Agreed, we’re ramping up service centers &amp; Tesla mobile service worldwide', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 24, 18, 12, 53)}   - Date:  2019-04-24 18:12:53
# Tweet:  {'text': '@Mike_Mitrakos More like $1000, but varies by country due to big differences in tax', 'sentiment': 'positive', 'polarity': 0.125, 'date': datetime.datetime(2019, 4, 24, 18, 11, 27)}   - Date:  2019-04-24 18:11:27
# Tweet:  {'text': '@patfan198010 Considering', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 24, 18, 9, 50)}   - Date:  2019-04-24 18:09:50
# Tweet:  {'text': 'As mentioned before, Tesla full self-driving option price will increase after May 1. You can order online at https://t.co/46TXqRrsdr.', 'sentiment': 'positive', 'polarity': 0.35, 'date': datetime.datetime(2019, 4, 24, 18, 9, 12)}   - Date:  2019-04-24 18:09:12
# Tweet:  {'text': '@Pornhub Like blowing twigs too?', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 24, 6, 55, 29)}   - Date:  2019-04-24 06:55:29
# Tweet:  {'text': '@rainnwilson Nope 😜', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 24, 4, 6, 19)}   - Date:  2019-04-24 04:06:19
# Tweet:  {'text': 'Motor Trend on Model S updates https://t.co/Lw9kfkWM33', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 24, 2, 18, 9)}   - Date:  2019-04-24 02:18:09
# Tweet:  {'text': 'Model S drives from San Francisco to Los Angeles without recharging https://t.co/cYiinwWBqd', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 24, 2, 15, 28)}   - Date:  2019-04-24 02:15:28
# Tweet:  {'text': '@MKBHD Strange but true', 'sentiment': 'positive', 'polarity': 0.15, 'date': datetime.datetime(2019, 4, 24, 1, 53, 45)}   - Date:  2019-04-24 01:53:45
# Tweet:  {'text': '@jeffaandrews @Tesla This require hardware', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 24, 1, 8, 49)}   - Date:  2019-04-24 01:08:49
# Tweet:  {'text': 'Can order online in 2 mins for home delivery &amp; return in 7 days for full refund https://t.co/46TXqRrsdr', 'sentiment': 'positive', 'polarity': 0.35, 'date': datetime.datetime(2019, 4, 24, 1, 2, 54)}   - Date:  2019-04-24 01:02:54
# Tweet:  {'text': 'New Model S has 370 mile / 595 km range https://t.co/D6bY7F2wUT', 'sentiment': 'positive', 'polarity': 0.13636363636363635, 'date': datetime.datetime(2019, 4, 24, 1, 0, 18)}   - Date:  2019-04-24 01:00:18
# Tweet:  {'text': '@MKBHD Perhaps the Internet has some helpful suggestions?', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 24, 0, 24, 32)}   - Date:  2019-04-24 00:24:32
# Tweet:  {'text': '@MKBHD Can’t think of anything', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 24, 0, 22, 29)}   - Date:  2019-04-24 00:22:29
# Tweet:  {'text': 'RT @Tesla: This 3D reconstruction shows the immense amount of depth information a Tesla can collect from just a few seconds of video from t…', 'sentiment': 'negative', 'polarity': -0.1, 'date': datetime.datetime(2019, 4, 24, 0, 19, 28)}   - Date:  2019-04-24 00:19:28
# Tweet:  {'text': '@joshandscomb @EGOPowerPlus Someone else thought of an electric 🍁🍃🍂 blower first? What!?', 'sentiment': 'positive', 'polarity': 0.3125, 'date': datetime.datetime(2019, 4, 24, 0, 15, 36)}   - Date:  2019-04-24 00:15:36
# Tweet:  {'text': 'Tesla blows haha', 'sentiment': 'positive', 'polarity': 0.2, 'date': datetime.datetime(2019, 4, 24, 0, 10, 12)}   - Date:  2019-04-24 00:10:12
# Tweet:  {'text': '@justadood We can probably just repurpose Model 3 HVAC parts. Not a big deal.', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 23, 23, 59, 31)}   - Date:  2019-04-23 23:59:31
# Tweet:  {'text': '@flcnhvy @ItsMurphyOMG True', 'sentiment': 'positive', 'polarity': 0.35, 'date': datetime.datetime(2019, 4, 23, 23, 57, 22)}   - Date:  2019-04-23 23:57:22
# Tweet:  {'text': '@JasonCross00 Long lasting battery + fast recharge &gt; pack swap', 'sentiment': 'positive', 'polarity': 0.05000000000000001, 'date': datetime.datetime(2019, 4, 23, 23, 56, 24)}   - Date:  2019-04-23 23:56:24
# Tweet:  {'text': '@ItsMurphyOMG Haha ok', 'sentiment': 'positive', 'polarity': 0.35, 'date': datetime.datetime(2019, 4, 23, 23, 54, 54)}   - Date:  2019-04-23 23:54:54
# Tweet:  {'text': '@AlvaroLuken @rainnwilson It’s been suggested by many, externally &amp; internally', 'sentiment': 'positive', 'polarity': 0.16666666666666666, 'date': datetime.datetime(2019, 4, 23, 23, 53, 33)}   - Date:  2019-04-23 23:53:33
# Tweet:  {'text': '@WhosImmortal Aren’t there good ones already?', 'sentiment': 'positive', 'polarity': 0.7, 'date': datetime.datetime(2019, 4, 23, 23, 39, 56)}   - Date:  2019-04-23 23:39:56
# Tweet:  {'text': '@ryancarlmercer Maybe add a particulate filter on inlet', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 23, 23, 37, 46)}   - Date:  2019-04-23 23:37:46
# Tweet:  {'text': 'Tesla is going to develop a quiet, electric leafblower', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 23, 23, 26, 50)}   - Date:  2019-04-23 23:26:50
# Tweet:  {'text': '@FredericLambert Yeah, there was a major change in last several months. Everyone noticed, Fred. Hello.', 'sentiment': 'positive', 'polarity': 0.020833333333333332, 'date': datetime.datetime(2019, 4, 23, 22, 50, 8)}   - Date:  2019-04-23 22:50:08
# Tweet:  {'text': '@FancyPantless @FredericLambert @Tesla Will do', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 23, 22, 47, 50)}   - Date:  2019-04-23 22:47:50
# Tweet:  {'text': '@Torgo82 @FredericLambert Absolutely', 'sentiment': 'positive', 'polarity': 0.2, 'date': datetime.datetime(2019, 4, 23, 22, 46, 4)}   - Date:  2019-04-23 22:46:04
# Tweet:  {'text': '@billseymour Seriously', 'sentiment': 'negative', 'polarity': -0.3333333333333333, 'date': datetime.datetime(2019, 4, 23, 22, 44, 38)}   - Date:  2019-04-23 22:44:38
# Tweet:  {'text': '@FredericLambert Also, how did you manage to get shamed into being de facto anti-Tesla by social media trolls. Jeez …', 'sentiment': 'positive', 'polarity': 0.03333333333333333, 'date': datetime.datetime(2019, 4, 23, 22, 43, 48)}   - Date:  2019-04-23 22:43:48
# Tweet:  {'text': '@FredericLambert Fred, every fire *is* investigated. Problem is those who only write about 0 injury Tesla fires while ignoring fatal combustion car fires or fail to mention any contextual statistics in their article, misleading readers into thinking EV’s have high fire risk when opposite is true.', 'sentiment': 'positive', 'polarity': 0.0020000000000000018, 'date': datetime.datetime(2019, 4, 23, 22, 42, 6)}   - Date:  2019-04-23 22:42:06
# Tweet:  {'text': '@teslaownersSV @jeffleach Thanks, support super appreciated', 'sentiment': 'positive', 'polarity': 0.24444444444444446, 'date': datetime.datetime(2019, 4, 23, 22, 32, 35)}   - Date:  2019-04-23 22:32:35
# Tweet:  {'text': '@jeffleach Sad if true 😔', 'sentiment': 'negative', 'polarity': -0.07500000000000001, 'date': datetime.datetime(2019, 4, 23, 21, 37, 56)}   - Date:  2019-04-23 21:37:56
# Tweet:  {'text': 'When you read double standard articles about Tesla, please ask why. Maybe there’s a good reason that isn’t obvious.', 'sentiment': 'positive', 'polarity': 0.175, 'date': datetime.datetime(2019, 4, 23, 21, 36, 23)}   - Date:  2019-04-23 21:36:23
# Tweet:  {'text': 'Reality is a Tesla, like most electric cars, is over 500% *less* likely to catch fire than combustion engine cars, which carry massive amounts of highly flammable fuel. Why is this never mentioned?', 'sentiment': 'positive', 'polarity': 0.09866666666666668, 'date': datetime.datetime(2019, 4, 23, 21, 33, 42)}   - Date:  2019-04-23 21:33:42
# Tweet:  {'text': 'Over a million combustion engine (it’s right there in the name!) car fires per year &amp; thousands of deaths, but one Tesla car fire with no injuries gets biggest headlines. Why the double standard? This is a real question.', 'sentiment': 'positive', 'polarity': 0.1392857142857143, 'date': datetime.datetime(2019, 4, 23, 21, 28, 29)}   - Date:  2019-04-23 21:28:29
# Tweet:  {'text': 'Those who predicted Tesla &amp; EVs would be dead &amp; autonomy would never happen are same people attacking Tesla today for 6-12 month delays, while ignoring major automakers 5+ years late. Why the double standard?', 'sentiment': 'negative', 'polarity': -0.07291666666666667, 'date': datetime.datetime(2019, 4, 23, 21, 9, 42)}   - Date:  2019-04-23 21:09:42
# Tweet:  {'text': 'Almost all coverage back then said hydrogen fuel cells would destroy electric cars &amp; autonomy was between 10 years &amp; never … https://t.co/bT2ZbnN8Yd', 'sentiment': 'negative', 'polarity': -0.1, 'date': datetime.datetime(2019, 4, 23, 20, 59, 18)}   - Date:  2019-04-23 20:59:18
# Tweet:  {'text': 'RT @Tesla: Tesla Vision uses path prediction to accurately predict how a road will extend, even when it can’t see around the corner https:/…', 'sentiment': 'positive', 'polarity': 0.4000000000000001, 'date': datetime.datetime(2019, 4, 23, 20, 6, 36)}   - Date:  2019-04-23 20:06:36
# Tweet:  {'text': '@martinengwicht @msitver @FrankLuntz Anti-matter def wins on energy density 🤣🤣', 'sentiment': 'positive', 'polarity': 0.3, 'date': datetime.datetime(2019, 4, 23, 20, 5, 44)}   - Date:  2019-04-23 20:05:44
# Tweet:  {'text': '@msitver @FrankLuntz Exactly. By end of this quarter, about half a million Teslas will have full self-driving hardware (pending computer swap) &amp; we will make another half million FSD cars by mid next year.', 'sentiment': 'positive', 'polarity': 0.04444444444444445, 'date': datetime.datetime(2019, 4, 23, 19, 3, 7)}   - Date:  2019-04-23 19:03:07
# Tweet:  {'text': '@ValueAnalyst1 @peterdevietien @scottwww @karpathy @Tesla @nvidia As a robotaxi, probably closer to 16 hours, accounting for empty legs, travel to charger/cleaning/service, wait times, etc. ~30 mile penalty most likely imo over ~120 paid miles. Impact is signicant for electricity cost, battery wear cost &amp; larger range pack needed.', 'sentiment': 'positive', 'polarity': 0.1, 'date': datetime.datetime(2019, 4, 23, 19, 0, 36)}   - Date:  2019-04-23 19:00:36
# Tweet:  {'text': 'RT @Tesla: Our new Full Self-Driving Chip houses 6 billion transistors and is capable of processing up to 2300 frames per second – a 21x im…', 'sentiment': 'positive', 'polarity': 0.17159090909090907, 'date': datetime.datetime(2019, 4, 23, 13, 52, 1)}   - Date:  2019-04-23 13:52:01
# Tweet:  {'text': '@ILuvAmp @ray4yu @tsport100 @Tesla Over a quarter million gasoline vehicle fires per year in USA alone https://t.co/xoaK6v6T6f', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 23, 13, 42, 35)}   - Date:  2019-04-23 13:42:35
# Tweet:  {'text': '@dasbub @SigITConsult @Tesla Anyone who did this analysis should interview at Tesla', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 23, 6, 33, 24)}   - Date:  2019-04-23 06:33:24
# Tweet:  {'text': '@RossSheingold @Tesla Upgrading hardware is not important for a few months', 'sentiment': 'negative', 'polarity': -0.2, 'date': datetime.datetime(2019, 4, 23, 6, 2, 25)}   - Date:  2019-04-23 06:02:25
# Tweet:  {'text': '@flcnhvy Is that a real billboard?', 'sentiment': 'positive', 'polarity': 0.2, 'date': datetime.datetime(2019, 4, 23, 5, 40, 27)}   - Date:  2019-04-23 05:40:27
# Tweet:  {'text': '@teslaownersSV @scottwww @ValueAnalyst1 @karpathy @Tesla @nvidia We’ll let the NN loose on Track Mode one day … that’ll be insane', 'sentiment': 'negative', 'polarity': -0.5384615384615384, 'date': datetime.datetime(2019, 4, 23, 5, 36, 56)}   - Date:  2019-04-23 05:36:56
# Tweet:  {'text': '@dasbub @SigITConsult @Tesla Reddit is hardcore. Mostly correct analysis. Comments so dark …', 'sentiment': 'positive', 'polarity': 0.175, 'date': datetime.datetime(2019, 4, 23, 5, 34, 49)}   - Date:  2019-04-23 05:34:49
# Tweet:  {'text': '@scottwww @ValueAnalyst1 @karpathy @Tesla @nvidia Or maybe pegging', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 23, 5, 3, 48)}   - Date:  2019-04-23 05:03:48
# Tweet:  {'text': '@xandriteme @scottwww @ValueAnalyst1 @karpathy @Tesla @nvidia On yeah, that too', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 23, 5, 1, 6)}   - Date:  2019-04-23 05:01:06
# Tweet:  {'text': '@scottwww @ValueAnalyst1 @karpathy @Tesla @nvidia Exactly. Also, you can’t actually use computation from a separate GPU effectively, as you get choked on the bus, so most of the computation is irrelevant. High power, high cooling, but low true, usable TOPS. Worst of all worlds.', 'sentiment': 'positive', 'polarity': 0.052000000000000005, 'date': datetime.datetime(2019, 4, 23, 4, 59, 5)}   - Date:  2019-04-23 04:59:05
# Tweet:  {'text': 'Full Self-Driving video\nhttps://t.co/9ESU8LLGFU', 'sentiment': 'positive', 'polarity': 0.35, 'date': datetime.datetime(2019, 4, 23, 1, 41, 29)}   - Date:  2019-04-23 01:41:29
# Tweet:  {'text': '@RossSheingold @Tesla All Model 3’s ever made can upgrade', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 23, 0, 56, 15)}   - Date:  2019-04-23 00:56:15
# Tweet:  {'text': 'Warning, this presentation is 4 hrs &amp; 20 mins long', 'sentiment': 'negative', 'polarity': -0.05, 'date': datetime.datetime(2019, 4, 23, 0, 38, 15)}   - Date:  2019-04-23 00:38:15
# Tweet:  {'text': '@DrewAdamTepper @craighamnett @Royaljester62 @Tesla Exactly', 'sentiment': 'positive', 'polarity': 0.25, 'date': datetime.datetime(2019, 4, 23, 0, 26, 5)}   - Date:  2019-04-23 00:26:05
# Tweet:  {'text': '@russotalks All cars made since Oct 2016 either have the hardware needed for FSD or are trivially upgradeable', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 23, 0, 24, 2)}   - Date:  2019-04-23 00:24:02
# Tweet:  {'text': 'RT @Tesla: All Tesla cars being built today have the hardware necessary for full self-driving:\n \n8 vision cameras, 12 ultrasonic sensors, r…', 'sentiment': 'positive', 'polarity': 0.175, 'date': datetime.datetime(2019, 4, 23, 0, 15, 52)}   - Date:  2019-04-23 00:15:52
# Tweet:  {'text': '@Royaljester62 @Tesla Yeah, will post soon', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 23, 0, 15, 30)}   - Date:  2019-04-23 00:15:30
# Tweet:  {'text': '@RyanHummer It’s automatic', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 23, 0, 15, 16)}   - Date:  2019-04-23 00:15:16
# Tweet:  {'text': 'Tesla Full Self-Driving\nhttps://t.co/pggm5ohVJC', 'sentiment': 'positive', 'polarity': 0.35, 'date': datetime.datetime(2019, 4, 23, 0, 10, 12)}   - Date:  2019-04-23 00:10:12
# Tweet:  {'text': 'Happy Home Planet Day!', 'sentiment': 'positive', 'polarity': 1.0, 'date': datetime.datetime(2019, 4, 22, 17, 18, 57)}   - Date:  2019-04-22 17:18:57
# Tweet:  {'text': 'RT @Space_Station: There may be no better view of Earth than from the International Space Station. In honor of #EarthDay, enjoy these photo…', 'sentiment': 'positive', 'polarity': 0.05000000000000001, 'date': datetime.datetime(2019, 4, 22, 16, 1, 53)}   - Date:  2019-04-22 16:01:53
# Tweet:  {'text': 'Full Metal Alchemy https://t.co/7UMaanRG8t', 'sentiment': 'positive', 'polarity': 0.35, 'date': datetime.datetime(2019, 4, 22, 8, 40, 31)}   - Date:  2019-04-22 08:40:31
# Tweet:  {'text': '@The_PlugSeeker @ElonsBrain @TheMERL @JohnCleese @EricIdle Love that movie!', 'sentiment': 'positive', 'polarity': 0.625, 'date': datetime.datetime(2019, 4, 22, 7, 46, 50)}   - Date:  2019-04-22 07:46:50
# Tweet:  {'text': '@Sofiaan @Tesla Actual Tesla range is about 5 miles / 8 km past zero', 'sentiment': 'negative', 'polarity': -0.125, 'date': datetime.datetime(2019, 4, 22, 7, 28, 11)}   - Date:  2019-04-22 07:28:11
# Tweet:  {'text': '@jlist ♥️ 🇯🇵', 'sentiment': 'positive', 'polarity': 1.0, 'date': datetime.datetime(2019, 4, 21, 21, 8, 43)}   - Date:  2019-04-21 21:08:43
# Tweet:  {'text': '@moyn1ckzanyat правда', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 21, 8, 43, 24)}   - Date:  2019-04-21 08:43:24
# Tweet:  {'text': '@v_g_fischer @4thFromOurStar Coming soon', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 21, 8, 41, 41)}   - Date:  2019-04-21 08:41:41
# Tweet:  {'text': '@4thFromOurStar Already have one', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 21, 8, 38, 16)}   - Date:  2019-04-21 08:38:16
# Tweet:  {'text': 'Respawn++ https://t.co/YvovV7VIOR', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 21, 5, 8, 18)}   - Date:  2019-04-21 05:08:18
# Tweet:  {'text': 'The Internet is insane', 'sentiment': 'negative', 'polarity': -1.0, 'date': datetime.datetime(2019, 4, 21, 3, 59, 42)}   - Date:  2019-04-21 03:59:42
# Tweet:  {'text': '@flcnhvy @loadiabe86 @skabooshka @GroggyTBear @BarkMSmeagol @FitzsimmonsK @DWildemuth @handytsla @TeslaBull @VW Never seen anything like it. Tesla is just trying to make electric cars &amp; solar power for a better future for all. True, we might not succeed, but why do they want us to fail?', 'sentiment': 'positive', 'polarity': 0.0875, 'date': datetime.datetime(2019, 4, 21, 0, 37, 2)}   - Date:  2019-04-21 00:37:02
# Tweet:  {'text': '@Senior__Hunter Milady, my shield is yours', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 21, 0, 1, 54)}   - Date:  2019-04-21 00:01:54
# Tweet:  {'text': '@loadiabe86 @skabooshka @GroggyTBear @BarkMSmeagol @FitzsimmonsK @DWildemuth @handytsla @TeslaBull This is extremely messed up. @VW, what’s going on?', 'sentiment': 'negative', 'polarity': -0.125, 'date': datetime.datetime(2019, 4, 20, 23, 58, 36)}   - Date:  2019-04-20 23:58:36
# Tweet:  {'text': '@weerhov Говорят, что кур доят', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 20, 20, 22, 35)}   - Date:  2019-04-20 20:22:35
# Tweet:  {'text': '@Wenger57793371 @d_svtrs Вот где собака зарыта', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 20, 20, 18, 51)}   - Date:  2019-04-20 20:18:51
# Tweet:  {'text': '@d_svtrs где инопланетяне?', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 20, 20, 9, 45)}   - Date:  2019-04-20 20:09:45
# Tweet:  {'text': '🦆 FTW', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 20, 1, 35, 56)}   - Date:  2019-04-20 01:35:56
# Tweet:  {'text': '@universal_sci We are very tiny', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 20, 1, 34, 45)}   - Date:  2019-04-20 01:34:45
# Tweet:  {'text': '@Model3Owners Put water repellant coating on radar, dark rectangle just below nose. Anything hydrophobic from hardware store or Tesla service can do it.', 'sentiment': 'negative', 'polarity': -0.15, 'date': datetime.datetime(2019, 4, 19, 23, 41, 35)}   - Date:  2019-04-19 23:41:35
# Tweet:  {'text': '@EricIdle @The_PlugSeeker @ElonsBrain @TheMERL @Tesla ♥️♥️♥️ 🐍🐍🐍 ♥️♥️♥️', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 19, 22, 58, 17)}   - Date:  2019-04-19 22:58:17
# Tweet:  {'text': 'Bach is killing it on YouTube https://t.co/51B1jQPjFY', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 19, 22, 51, 31)}   - Date:  2019-04-19 22:51:31
# Tweet:  {'text': '@LeedsMuseums @TheMERL I love your castle', 'sentiment': 'positive', 'polarity': 0.5, 'date': datetime.datetime(2019, 4, 19, 18, 53, 6)}   - Date:  2019-04-19 18:53:06
# Tweet:  {'text': '@TheMERL Ewe’re a winsome eyre', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 19, 18, 44, 6)}   - Date:  2019-04-19 18:44:06
# Tweet:  {'text': '@LarryPanozzo Nice', 'sentiment': 'positive', 'polarity': 0.6, 'date': datetime.datetime(2019, 4, 19, 18, 19, 37)}   - Date:  2019-04-19 18:19:37
# Tweet:  {'text': 'Back to work …', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 19, 18, 16, 2)}   - Date:  2019-04-19 18:16:02
# Tweet:  {'text': '🐏', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 19, 18, 9, 42)}   - Date:  2019-04-19 18:09:42
# Tweet:  {'text': '@TheMERL @Berkshire_show Are you me or are you you?', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 19, 17, 35, 50)}   - Date:  2019-04-19 17:35:50
# Tweet:  {'text': '@ElonsBrain @TheMERL My fav color is blue, no red, aaargh …', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 19, 17, 34, 58)}   - Date:  2019-04-19 17:34:58
# Tweet:  {'text': '@TheMERL New uWu https://t.co/kvlqvNq3Cg', 'sentiment': 'positive', 'polarity': 0.13636363636363635, 'date': datetime.datetime(2019, 4, 19, 17, 29, 37)}   - Date:  2019-04-19 17:29:37
# Tweet:  {'text': '@TheMERL Old ewe https://t.co/tTmOPWUAUp', 'sentiment': 'positive', 'polarity': 0.1, 'date': datetime.datetime(2019, 4, 19, 17, 2, 25)}   - Date:  2019-04-19 17:02:25
# Tweet:  {'text': '@CleopatraOwen17 @neuralink It’s USB-C', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 19, 16, 46, 12)}   - Date:  2019-04-19 16:46:12
# Tweet:  {'text': '@CleopatraOwen17 @HiThomasMorelli @TheMERL It works great!', 'sentiment': 'positive', 'polarity': 1.0, 'date': datetime.datetime(2019, 4, 19, 16, 33, 30)}   - Date:  2019-04-19 16:33:30
# Tweet:  {'text': '@TheMERL Haha', 'sentiment': 'positive', 'polarity': 0.2, 'date': datetime.datetime(2019, 4, 19, 16, 31, 54)}   - Date:  2019-04-19 16:31:54
# Tweet:  {'text': '@TheMERL !', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 19, 10, 17, 50)}   - Date:  2019-04-19 10:17:50
# Tweet:  {'text': 'I meant lämpe. Where’s the edit function when you really need it!?', 'sentiment': 'positive', 'polarity': 0.25, 'date': datetime.datetime(2019, 4, 19, 10, 4, 50)}   - Date:  2019-04-19 10:04:50
# Tweet:  {'text': 'Just wants a little lamp 💡', 'sentiment': 'positive', 'polarity': 0.0062500000000000056, 'date': datetime.datetime(2019, 4, 19, 7, 31, 51)}   - Date:  2019-04-19 07:31:51
# Tweet:  {'text': 'The etymology of metaphorical entomology https://t.co/KdAkLD1cwW', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 19, 7, 30, 18)}   - Date:  2019-04-19 07:30:18
# Tweet:  {'text': '@EvaFoxU @shawnapandya @Bryson_M @techreview So cute', 'sentiment': 'positive', 'polarity': 0.5, 'date': datetime.datetime(2019, 4, 19, 7, 26, 10)}   - Date:  2019-04-19 07:26:10
# Tweet:  {'text': 'Original moth meme https://t.co/BYDQRzIine', 'sentiment': 'positive', 'polarity': 0.375, 'date': datetime.datetime(2019, 4, 19, 7, 25, 23)}   - Date:  2019-04-19 07:25:23
# Tweet:  {'text': 'Or a sheep', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 19, 7, 9, 29)}   - Date:  2019-04-19 07:09:29
# Tweet:  {'text': '@rune_ea @Erdayastronaut @DJSnM @torybruno @lrocket Exactly', 'sentiment': 'positive', 'polarity': 0.25, 'date': datetime.datetime(2019, 4, 19, 6, 37, 37)}   - Date:  2019-04-19 06:37:37
# Tweet:  {'text': '“Wake up sheeple!” - sheep', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 19, 6, 17, 57)}   - Date:  2019-04-19 06:17:57
# Tweet:  {'text': '@Erdayastronaut @DJSnM @torybruno @lrocket 🚀 propellant grade kerosene (basically, jet fuel) &amp; liquid oxygen are close, but H2 &amp; O2 are not', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 19, 5, 13, 50)}   - Date:  2019-04-19 05:13:50
# Tweet:  {'text': '@Erdayastronaut @DJSnM @torybruno @lrocket Common shaft only works if optimal rpm is similar for fuel &amp; oxidizer', 'sentiment': 'negative', 'polarity': -0.09999999999999999, 'date': datetime.datetime(2019, 4, 19, 5, 10, 56)}   - Date:  2019-04-19 05:10:56
# Tweet:  {'text': 'My Twitter is pretty much complete nonsense at this point', 'sentiment': 'positive', 'polarity': 0.175, 'date': datetime.datetime(2019, 4, 19, 4, 19, 50)}   - Date:  2019-04-19 04:19:50
# Tweet:  {'text': 'Like thug, but rural', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 19, 4, 18, 17)}   - Date:  2019-04-19 04:18:17
# Tweet:  {'text': 'Rürl Lœf', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 19, 4, 16, 23)}   - Date:  2019-04-19 04:16:23
# Tweet:  {'text': 'Switched souls with The Museum of English Rural Lofe https://t.co/X41ZWc9sip', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 19, 4, 14, 11)}   - Date:  2019-04-19 04:14:11
# Tweet:  {'text': 'But I’m just a simple sheep/ram', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 19, 0, 50, 11)}   - Date:  2019-04-19 00:50:11
# Tweet:  {'text': 'Universe is big, but rendering complexity is not https://t.co/VMnCJ7Vpw9', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 19, 0, 48, 45)}   - Date:  2019-04-19 00:48:45
# Tweet:  {'text': '@baconmashwbs @natfriedman Sheep replicants', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 18, 9, 19)}   - Date:  2019-04-18 09:19:00
# Tweet:  {'text': '@natfriedman Sheeps thank you 🙏', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 18, 8, 36, 44)}   - Date:  2019-04-18 08:36:44
# Tweet:  {'text': '@shawnapandya @Bryson_M @techreview Are you good with sheep?', 'sentiment': 'positive', 'polarity': 0.7, 'date': datetime.datetime(2019, 4, 17, 19, 53, 17)}   - Date:  2019-04-17 19:53:17
# Tweet:  {'text': '@techreview I’m an absolute unit too https://t.co/Rf0BTJmeEN', 'sentiment': 'positive', 'polarity': 0.2, 'date': datetime.datetime(2019, 4, 17, 19, 43, 50)}   - Date:  2019-04-17 19:43:50
# Tweet:  {'text': 'RT @Tesla: Our Kettleman City Supercharger station has 40 stalls, 250kW of solar, 5 Powerpacks and a coffee lounge for owners to recharge w…', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 17, 17, 37, 10)}   - Date:  2019-04-17 17:37:10
# Tweet:  {'text': 'RT @m_xalher: MAJOR @tesla demand catalyst in Europe: Gas savings\n\nPetrol is very costly here. Norway: NOK 17/liter (USD 7.8/gallon). Elect…', 'sentiment': 'positive', 'polarity': 0.13125, 'date': datetime.datetime(2019, 4, 17, 7, 52, 22)}   - Date:  2019-04-17 07:52:22
# Tweet:  {'text': '@shraddha_261291 @WhatTheFFacts Yeah, gave everything I had to Tesla in Dec 2008', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 16, 23, 18, 17)}   - Date:  2019-04-16 23:18:17
# Tweet:  {'text': '@sjensenknight It’s not a big deal. Charge to 90% to 95% &amp; you’ll be fine. At 100% state of charge, regen braking doesn’t work, because the battery is full, so car is less energy efficient.', 'sentiment': 'positive', 'polarity': 0.15, 'date': datetime.datetime(2019, 4, 16, 18, 51, 39)}   - Date:  2019-04-16 18:51:39
# Tweet:  {'text': '@iliketeslas Haha', 'sentiment': 'positive', 'polarity': 0.2, 'date': datetime.datetime(2019, 4, 16, 6, 59, 49)}   - Date:  2019-04-16 06:59:49
# Tweet:  {'text': '@houmanhemmati @CathieDWood @ARKInvest @TashaARK @skorusARK Yes', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 16, 5, 13, 42)}   - Date:  2019-04-16 05:13:42
# Tweet:  {'text': 'RT @CathieDWood: .@ARKInvest’s research suggests that the Model 3 will generate cash flow of $10,000 per year at a minimum on an #autonomou…', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 16, 5, 8, 22)}   - Date:  2019-04-16 05:08:22
# Tweet:  {'text': '@theRedding @Erdayastronaut Rockets are not yet safe enough to fly over land', 'sentiment': 'positive', 'polarity': 0.43333333333333335, 'date': datetime.datetime(2019, 4, 16, 5, 6, 57)}   - Date:  2019-04-16 05:06:57
# Tweet:  {'text': '@GameSyns @Erdayastronaut Engines seem ok, pending inspection', 'sentiment': 'positive', 'polarity': 0.5, 'date': datetime.datetime(2019, 4, 16, 5, 3, 24)}   - Date:  2019-04-16 05:03:24
# Tweet:  {'text': '@Erdayastronaut It can, but the attachment fixtures are different from standard F9 &amp; they weren’t ready in time', 'sentiment': 'positive', 'polarity': 0.06666666666666667, 'date': datetime.datetime(2019, 4, 16, 5, 0, 58)}   - Date:  2019-04-16 05:00:58
# Tweet:  {'text': 'RT @WorldAndScience: Gorgeous high resolution shot of Falcon Heavy thrusters! https://t.co/XbhGl6KT8K', 'sentiment': 'positive', 'polarity': 0.21999999999999997, 'date': datetime.datetime(2019, 4, 15, 23, 46, 21)}   - Date:  2019-04-15 23:46:21
# Tweet:  {'text': '@mwischer18 Winter in snowfall is so beautiful', 'sentiment': 'positive', 'polarity': 0.85, 'date': datetime.datetime(2019, 4, 15, 4, 17, 9)}   - Date:  2019-04-15 04:17:09
# Tweet:  {'text': '@gauty23 I’m actually less crazy in person … or am I? 🤔', 'sentiment': 'negative', 'polarity': -0.3833333333333333, 'date': datetime.datetime(2019, 4, 15, 4, 14, 6)}   - Date:  2019-04-15 04:14:06
# Tweet:  {'text': 'I was always crazy on Twitter fyi', 'sentiment': 'negative', 'polarity': -0.6, 'date': datetime.datetime(2019, 4, 15, 4, 11, 1)}   - Date:  2019-04-15 04:11:01
# Tweet:  {'text': '@ThisMemeyGuy Yes', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 15, 4, 0, 44)}   - Date:  2019-04-15 04:00:44
# Tweet:  {'text': '@TobyTurner Haha true. I actually love horses.', 'sentiment': 'positive', 'polarity': 0.35000000000000003, 'date': datetime.datetime(2019, 4, 15, 3, 59, 5)}   - Date:  2019-04-15 03:59:05
# Tweet:  {'text': 'Buying a car in 2019 that can’t upgrade to full self-driving is like buying a horse instead of a car in 1919 https://t.co/oEjXdmyJiJ', 'sentiment': 'positive', 'polarity': 0.35, 'date': datetime.datetime(2019, 4, 15, 3, 55, 18)}   - Date:  2019-04-15 03:55:18
# Tweet:  {'text': 'RT @NASA: When we talk about the enormity of the cosmos💫, it’s easy to toss out big numbers, but far more difficult to wrap our minds aroun…', 'sentiment': 'positive', 'polarity': 0.10666666666666665, 'date': datetime.datetime(2019, 4, 15, 3, 32, 6)}   - Date:  2019-04-15 03:32:06
# Tweet:  {'text': '@officialjaden Love Just Water btw', 'sentiment': 'positive', 'polarity': 0.5, 'date': datetime.datetime(2019, 4, 15, 0, 21, 49)}   - Date:  2019-04-15 00:21:49
# Tweet:  {'text': '@teslaownersSV @DannyLaShep https://t.co/z9BVWS0O95', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 15, 0, 19, 31)}   - Date:  2019-04-15 00:19:31
# Tweet:  {'text': '@DannyLaShep With steel membrane wings like a Dragon, we may be able to lower Starship’s orbital reentry temp to ~1000 degrees C, which would allow the whole surface to be uncooled bare metal', 'sentiment': 'positive', 'polarity': 0.25, 'date': datetime.datetime(2019, 4, 15, 0, 11, 11)}   - Date:  2019-04-15 00:11:11
# Tweet:  {'text': '@jasonsellspa Starship will land on a ring of fire', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 14, 23, 31, 42)}   - Date:  2019-04-14 23:31:42
# Tweet:  {'text': '@JaneidyEve 6.5', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 14, 23, 10, 17)}   - Date:  2019-04-14 23:10:17
# Tweet:  {'text': '@Johankyu7 Yes', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 14, 23, 6, 20)}   - Date:  2019-04-14 23:06:20
# Tweet:  {'text': 'Winter is coming', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 14, 23, 2, 20)}   - Date:  2019-04-14 23:02:20
# Tweet:  {'text': 'Thinking about adding giant stainless steel dragon wings to Starship', 'sentiment': 'positive', 'polarity': 0.1, 'date': datetime.datetime(2019, 4, 14, 23, 1, 59)}   - Date:  2019-04-14 23:01:59
# Tweet:  {'text': '@EforElectric @WSJ That tweet did take immense effort 🤣🤣 Fair point tho. Powerwall production is now ramping fast. Tesla was cell-starved last year, so we had to switch all lines to make packs for cars, which meant Powerwall production was living off scraps.', 'sentiment': 'positive', 'polarity': 0.22499999999999998, 'date': datetime.datetime(2019, 4, 14, 22, 54, 51)}   - Date:  2019-04-14 22:54:51
# Tweet:  {'text': '@yourloyalpal @SComet04 @WSJ Deal', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 14, 22, 46, 27)}   - Date:  2019-04-14 22:46:27
# Tweet:  {'text': 'Please support my campaign to rebrand @WSJ as \U0001f9e6 emoji!', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 14, 22, 21, 39)}   - Date:  2019-04-14 22:21:39
# Tweet:  {'text': '@AustinOnSocial @TheOnion 🔥🔥💕💕💫💫😀😀', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 14, 22, 18, 17)}   - Date:  2019-04-14 22:18:17
# Tweet:  {'text': 'At some point, @TheOnion and I should just a get a room …', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 14, 22, 17, 15)}   - Date:  2019-04-14 22:17:15
# Tweet:  {'text': '@techreview Just use this handy guide https://t.co/wWZGuNpe5f', 'sentiment': 'positive', 'polarity': 0.6, 'date': datetime.datetime(2019, 4, 14, 22, 14, 16)}   - Date:  2019-04-14 22:14:16
# Tweet:  {'text': '@sanjeev_r11 @cleantechnica @lexfridman Yes', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 14, 21, 1, 38)}   - Date:  2019-04-14 21:01:38
# Tweet:  {'text': '@cleantechnica Good interview by @lexfridman', 'sentiment': 'positive', 'polarity': 0.7, 'date': datetime.datetime(2019, 4, 14, 20, 59, 30)}   - Date:  2019-04-14 20:59:30
# Tweet:  {'text': '@Louisbotelho17 @Kristennetten @arctechinc @danahull @GinoG01328427 @Savis1949 @WSJ @Tesla @SEC_Enforcement Truth', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 14, 20, 46, 39)}   - Date:  2019-04-14 20:46:39
# Tweet:  {'text': '@johnrobb Exactly', 'sentiment': 'positive', 'polarity': 0.25, 'date': datetime.datetime(2019, 4, 14, 20, 42, 39)}   - Date:  2019-04-14 20:42:39
# Tweet:  {'text': '@Kristennetten @arctechinc @danahull @GinoG01328427 @Savis1949 @WSJ @Tesla @SEC_Enforcement How embarrassing. Will change.', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 14, 20, 36, 10)}   - Date:  2019-04-14 20:36:10
# Tweet:  {'text': '@Chapter11Cases We will. You read it right.', 'sentiment': 'positive', 'polarity': 0.2857142857142857, 'date': datetime.datetime(2019, 4, 14, 20, 33, 46)}   - Date:  2019-04-14 20:33:46
# Tweet:  {'text': '@arctechinc @danahull @GinoG01328427 @Savis1949 @WSJ @Tesla @SEC_Enforcement Haha true', 'sentiment': 'positive', 'polarity': 0.275, 'date': datetime.datetime(2019, 4, 14, 20, 31, 17)}   - Date:  2019-04-14 20:31:17
# Tweet:  {'text': '@martinengwicht @KnightmarArchon @EvBite @johnrobb @Tesla @ElonMuskScience I’ve always thought that the fundamental good of Tesla should be measured by the number of years by which it accelerates the transition to sustainable transport &amp; energy', 'sentiment': 'positive', 'polarity': 0.7, 'date': datetime.datetime(2019, 4, 14, 20, 7, 13)}   - Date:  2019-04-14 20:07:13
# Tweet:  {'text': '@cSharp3x7 @Savis1949 @WSJ Good point, small oil is a problem too', 'sentiment': 'positive', 'polarity': 0.22499999999999998, 'date': datetime.datetime(2019, 4, 14, 20, 3, 48)}   - Date:  2019-04-14 20:03:48
# Tweet:  {'text': '@FredericLambert @GilesGraves @Savis1949 @WSJ I’m sorry, Fred, but WSJ has relentlessly attacked Tesla with bogus articles for over a decade. They can’t *all* be chalked up to poor reporting. Where are the WSJ exposé pieces on oil, coal &amp; gas? That industry is 1000 times bigger than Tesla. Perhaps they’re all angels …', 'sentiment': 'negative', 'polarity': -0.3, 'date': datetime.datetime(2019, 4, 14, 20, 0, 31)}   - Date:  2019-04-14 20:00:31
# Tweet:  {'text': '@GinoG01328427 @Savis1949 @WSJ @Tesla Yes, this was an utter boldface (literally) lie! Unbelievable that WSJ would write something so false.', 'sentiment': 'negative', 'polarity': -0.2166666666666667, 'date': datetime.datetime(2019, 4, 14, 19, 55, 4)}   - Date:  2019-04-14 19:55:04
# Tweet:  {'text': '@GilesGraves @Savis1949 @WSJ True, Bloomberg is almost as bad', 'sentiment': 'negative', 'polarity': -0.17499999999999993, 'date': datetime.datetime(2019, 4, 14, 19, 36, 50)}   - Date:  2019-04-14 19:36:50
# Tweet:  {'text': '@Savis1949 @WSJ Holman Jenkins &amp; WSJ in general are sock \U0001f9e6 puppets of big oil', 'sentiment': 'positive', 'polarity': 0.02500000000000001, 'date': datetime.datetime(2019, 4, 14, 19, 30, 35)}   - Date:  2019-04-14 19:30:35
# Tweet:  {'text': '@grzf_ Starship is kinda Gundam', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 14, 19, 29)}   - Date:  2019-04-14 19:29:00
# Tweet:  {'text': '@KnightmarArchon @EvBite @johnrobb Very much so. There are 2.5B cars &amp; trucks on Earth. Even replacing 1% of that fleet would require making 25M vehicles per year. Tesla will make over 500k cars in next 12 months, but that’s a mere 2% of 25M or 0.02% of global vehicle fleet. Car industry slow -&gt; demand &gt;&gt; supply.', 'sentiment': 'negative', 'polarity': -0.10800000000000001, 'date': datetime.datetime(2019, 4, 14, 19, 28, 11)}   - Date:  2019-04-14 19:28:11
# Tweet:  {'text': '@Teslarati Sentry Mode fundamentally empowers the individual car owner over entrenched interests, in this case a corrupt traffic judge. Even Tesla doesn’t have access to the video unless sent to us by owner.', 'sentiment': 'negative', 'polarity': -0.25, 'date': datetime.datetime(2019, 4, 14, 19, 19, 19)}   - Date:  2019-04-14 19:19:19
# Tweet:  {'text': '@nichegamer @NCBirbhan @CBSNews Mint berry crunch', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 14, 18, 22, 3)}   - Date:  2019-04-14 18:22:03
# Tweet:  {'text': '@Teslarati poetic justice', 'sentiment': 'positive', 'polarity': 0.375, 'date': datetime.datetime(2019, 4, 14, 18, 17, 53)}   - Date:  2019-04-14 18:17:53
# Tweet:  {'text': '@NCBirbhan @CBSNews Boring candy coming soon …', 'sentiment': 'negative', 'polarity': -1.0, 'date': datetime.datetime(2019, 4, 14, 9, 59, 33)}   - Date:  2019-04-14 09:59:33
# Tweet:  {'text': '@CBSNews Mr Buffett, please stop destroying Dairy Queen. In the name of all that is holy, please stop.', 'sentiment': 'negative', 'polarity': -0.2, 'date': datetime.datetime(2019, 4, 14, 9, 8, 48)}   - Date:  2019-04-14 09:08:48
# Tweet:  {'text': '@tsrandall Wow, a lot of people don’t know much about how manufacturing works! If you have peak capacity of X, actual average weekly output will necessarily be less than X. First 6-12 months, it will be much less than X. Impossible to predict exact production ramp S-curve.', 'sentiment': 'negative', 'polarity': -0.038888888888888876, 'date': datetime.datetime(2019, 4, 14, 8, 58, 12)}   - Date:  2019-04-14 08:58:12
# Tweet:  {'text': '@tsrandall There is 35 GWh/yr “theoretical capacity”, but actual max output is ~2/3. It was physically impossible to make more Model 3’s in Q1 due to cell constraints.', 'sentiment': 'negative', 'polarity': -0.05833333333333333, 'date': datetime.datetime(2019, 4, 14, 8, 42, 8)}   - Date:  2019-04-14 08:42:08
# Tweet:  {'text': '@CalinRoman3 @GregMatson Yes', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 13, 20, 32, 25)}   - Date:  2019-04-13 20:32:25
# Tweet:  {'text': '@GregMatson Yes, all cars with Autopilot 2.0 or higher, so ~400,000 of Tesla cars built to date', 'sentiment': 'positive', 'polarity': 0.25, 'date': datetime.datetime(2019, 4, 13, 19, 59, 2)}   - Date:  2019-04-13 19:59:02
# Tweet:  {'text': '@Erdayastronaut @kneibert Your interventions do train the NN, but we first verify that the training doesn’t cause other issues, so expect step rather than continuous changes in capability', 'sentiment': 'positive', 'polarity': 0.0625, 'date': datetime.datetime(2019, 4, 13, 19, 56, 42)}   - Date:  2019-04-13 19:56:42
# Tweet:  {'text': '@FredericLambert Yes', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 13, 19, 43, 17)}   - Date:  2019-04-13 19:43:17
# Tweet:  {'text': '@yaypie There will be that too, but economics will favor initial purchase', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 13, 19, 41, 42)}   - Date:  2019-04-13 19:41:42
# Tweet:  {'text': '@Rebel44CZ Hopefully have the order page live before then. If not, will push price change out a bit later.', 'sentiment': 'positive', 'polarity': 0.06818181818181818, 'date': datetime.datetime(2019, 4, 13, 19, 40, 50)}   - Date:  2019-04-13 19:40:50
# Tweet:  {'text': '@brandonbernicky @tsrandall Not good enough yet. Pushing release by a few weeks. Will be amazing.', 'sentiment': 'positive', 'polarity': 0.012500000000000011, 'date': datetime.datetime(2019, 4, 13, 19, 19, 30)}   - Date:  2019-04-13 19:19:30
# Tweet:  {'text': '@tsrandall Incorrect. Pana cell lines at Giga are only at ~24GWh/yr &amp; have been a constraint on Model 3 output since July. No choice but to use other suppliers for Powerwall/Powerpack cells. Tesla won’t spend money on more capacity until existing lines get closer to 35GWh theoretical.', 'sentiment': 'positive', 'polarity': 0.09375, 'date': datetime.datetime(2019, 4, 13, 19, 17, 46)}   - Date:  2019-04-13 19:17:46
# Tweet:  {'text': '@kneibert Tesla will start FSD computer upgrade in a few months', 'sentiment': 'negative', 'polarity': -0.2, 'date': datetime.datetime(2019, 4, 13, 17, 33, 19)}   - Date:  2019-04-13 17:33:19
# Tweet:  {'text': '@frozencanuck Something like that', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 13, 17, 31, 46)}   - Date:  2019-04-13 17:31:46
# Tweet:  {'text': 'Starting May 1', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 13, 17, 29, 59)}   - Date:  2019-04-13 17:29:59
# Tweet:  {'text': 'Please note that the price of the Tesla Full Self-Driving option will increase substantially over time', 'sentiment': 'positive', 'polarity': 0.35, 'date': datetime.datetime(2019, 4, 13, 17, 26, 58)}   - Date:  2019-04-13 17:26:58
# Tweet:  {'text': 'RT @pmoconne: Took ownership of M3 1yr ago\n- 27k miles, not one issue\n- Increased range by 10 miles\n- Sentry/Dog mode\n- Summon\n- Arcade gam…', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 13, 17, 6, 13)}   - Date:  2019-04-13 17:06:13
# Tweet:  {'text': '@JCzolko Coming this year', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 13, 17, 4, 13)}   - Date:  2019-04-13 17:04:13
# Tweet:  {'text': 'Lease a Tesla online in a few mins &amp; have it delivered to your house (return within 7 days for full refund) https://t.co/46TXqRrsdr', 'sentiment': 'positive', 'polarity': 0.07499999999999998, 'date': datetime.datetime(2019, 4, 13, 17, 2, 4)}   - Date:  2019-04-13 17:02:04
# Tweet:  {'text': '@CryptoCobain Cryptocurrency is my safe word', 'sentiment': 'positive', 'polarity': 0.5, 'date': datetime.datetime(2019, 4, 13, 16, 22, 16)}   - Date:  2019-04-13 16:22:16
# Tweet:  {'text': '@Gfilche Model 3 drive unit &amp; body is designed like a commercial truck for a million mile life. Current battery modules should last 300k to 500k miles (1500 cycles). Replacing modules (not pack) will only cost $5k to $7k.', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 13, 16, 18, 56)}   - Date:  2019-04-13 16:18:56
# Tweet:  {'text': '@Katharina_Lamsa @Tesla @TheFuturist007 @SweMFA @HansLak @SPittWalker @antgrasso @AkwyZ @TopCyberNews Cool', 'sentiment': 'positive', 'polarity': 0.35, 'date': datetime.datetime(2019, 4, 13, 16, 5, 56)}   - Date:  2019-04-13 16:05:56
# Tweet:  {'text': '@Gfilche On April 22, Investor Autonomy Day, Tesla will free investors from the tyranny of having to drive their own car', 'sentiment': 'positive', 'polarity': 0.5, 'date': datetime.datetime(2019, 4, 13, 16, 4, 59)}   - Date:  2019-04-13 16:04:59
# Tweet:  {'text': 'RT @johnrobb: “Buying a car today is an investment into the future. I think the most profound thing is that if you buy a Tesla today, I bel…', 'sentiment': 'positive', 'polarity': 0.19444444444444445, 'date': datetime.datetime(2019, 4, 13, 15, 56, 1)}   - Date:  2019-04-13 15:56:01
# Tweet:  {'text': "RT @DigitalTrends: This is how @Tesla's are made. https://t.co/5O7MZCGBN6", 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 13, 10, 17, 33)}   - Date:  2019-04-13 10:17:33
# Tweet:  {'text': '@techreview Uh it’s a simulation hello', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 13, 6, 26, 4)}   - Date:  2019-04-13 06:26:04
# Tweet:  {'text': 'RT @GovSisolak: Excited to see high school seniors from across Nevada interviewing for @Tesla’s Manufacturing Development Program. The 50-6…', 'sentiment': 'positive', 'polarity': 0.2675, 'date': datetime.datetime(2019, 4, 12, 21, 39, 41)}   - Date:  2019-04-12 21:39:41
# Tweet:  {'text': '@martinengwicht @MaldeShreyas Da Vinci biography', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 12, 20, 16)}   - Date:  2019-04-12 20:16:00
# Tweet:  {'text': '@JaneidyEve @MaldeShreyas Malala', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 12, 20, 13, 52)}   - Date:  2019-04-12 20:13:52
# Tweet:  {'text': '@AlecBenjamin That would be cool to do one day', 'sentiment': 'positive', 'polarity': 0.35, 'date': datetime.datetime(2019, 4, 12, 20, 6, 39)}   - Date:  2019-04-12 20:06:39
# Tweet:  {'text': "RT @lexfridman: Here's my conversation with @elonmusk on the Artificial Intelligence podcast. Focus was on Tesla Autopilot &amp; last week's re…", 'sentiment': 'negative', 'polarity': -0.3, 'date': datetime.datetime(2019, 4, 12, 18, 25, 58)}   - Date:  2019-04-12 18:25:58
# Tweet:  {'text': '@dennishegstad @Tesla Other automakers change prices constantly &amp; substantially by varying rebates &amp; discounts according to negotiating strength of buyer. Tesla is transparent &amp; consistent.', 'sentiment': 'positive', 'polarity': 0.041666666666666664, 'date': datetime.datetime(2019, 4, 12, 18, 24, 52)}   - Date:  2019-04-12 18:24:52
# Tweet:  {'text': '@dirtnapdragon @Tesla So if we raise prices in the future, will you cut Tesla a check? Can’t have it both ways.', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 12, 18, 12, 42)}   - Date:  2019-04-12 18:12:42
# Tweet:  {'text': '@Murph876 Ahem RHD', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 12, 18, 11, 38)}   - Date:  2019-04-12 18:11:38
# Tweet:  {'text': '@Murph876 LHD order page should be live within a few weeks. Deliveries start hopefully June/July.', 'sentiment': 'negative', 'polarity': -0.03181818181818183, 'date': datetime.datetime(2019, 4, 12, 15, 48, 26)}   - Date:  2019-04-12 15:48:26
# Tweet:  {'text': '@movingux @victor_leduc Coming this year', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 12, 15, 15, 48)}   - Date:  2019-04-12 15:15:48
# Tweet:  {'text': '@28delayslater @Tesla @mayemusk Good point', 'sentiment': 'positive', 'polarity': 0.7, 'date': datetime.datetime(2019, 4, 12, 15, 8, 18)}   - Date:  2019-04-12 15:08:18
# Tweet:  {'text': 'Leasing now available for Model 3 https://t.co/cz0TQn7IOZ', 'sentiment': 'positive', 'polarity': 0.4, 'date': datetime.datetime(2019, 4, 12, 14, 58, 33)}   - Date:  2019-04-12 14:58:33
# Tweet:  {'text': 'RT @SpaceX: Falcon Heavy’s side boosters land on Landing Zones 1 and 2 https://t.co/nJCCaVHOeo', 'sentiment': 'negative', 'polarity': -0.2, 'date': datetime.datetime(2019, 4, 12, 14, 55, 34)}   - Date:  2019-04-12 14:55:34
# Tweet:  {'text': 'RT @SpaceX: Liftoff of Falcon Heavy https://t.co/3oALJPOMBa', 'sentiment': 'negative', 'polarity': -0.2, 'date': datetime.datetime(2019, 4, 12, 14, 55, 32)}   - Date:  2019-04-12 14:55:32
# Tweet:  {'text': '@BarkMSmeagol @MaldeShreyas Samwise', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 12, 3, 20, 2)}   - Date:  2019-04-12 03:20:02
# Tweet:  {'text': '@MaldeShreyas Am basically doing continuous AMA on Twitter!', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2019, 4, 12, 2, 59, 5)}   - Date:  2019-04-12 02:59:05
# ...
# Tweet:  {'text': 'Boring Company Hyperloop will take you from city center under ground &amp; ocean to spaceport in 10 to 15 mins https://t.co/VhpfhgdXSd', 'sentiment': 'negative', 'polarity': -0.55, 'date': datetime.datetime(2018, 5, 16, 9, 59, 21)}   - Date:  2018-05-16 09:59:21
# Tweet:  {'text': 'RT @ElectrekCo: Tesla Model X breaks electric towing record by pulling a Qantas Boeing 787-9\xa0Dreamliner https://t.co/Ss104vfbcF by @frederi…', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 15, 9, 49, 55)}   - Date:  2018-05-15 09:49:55
# Tweet:  {'text': 'RT @Tesla: 140 Tesla Powerpacks now live in Belgium and balancing the European electrical grid 100 times faster than fossil fuel plants htt…', 'sentiment': 'positive', 'polarity': 0.06818181818181818, 'date': datetime.datetime(2018, 5, 15, 0, 46, 10)}   - Date:  2018-05-15 00:46:10
# Tweet:  {'text': '@andrewbg Time will tell, but so far it appears so', 'sentiment': 'positive', 'polarity': 0.1, 'date': datetime.datetime(2018, 5, 14, 21, 6, 27)}   - Date:  2018-05-14 21:06:27
# Tweet:  {'text': '@Kasabiii It certainly needs to be better &amp; we work to improve it every day, but perfect is enemy of good. A system that, on balance, saves lives &amp; reduces injuries should be released.', 'sentiment': 'positive', 'polarity': 0.6035714285714286, 'date': datetime.datetime(2018, 5, 14, 21, 3, 22)}   - Date:  2018-05-14 21:03:22
# Tweet:  {'text': 'What’s actually amazing about this accident is that a Model S hit a fire truck at 60mph and the driver only broke an ankle. An impact at that speed usually results in severe injury or death.', 'sentiment': 'positive', 'polarity': 0.1166666666666667, 'date': datetime.datetime(2018, 5, 14, 20, 57, 33)}   - Date:  2018-05-14 20:57:33
# Tweet:  {'text': 'It’s super messed up that a Tesla crash resulting in a broken ankle is front page news and the ~40,000 people who died in US auto accidents alone in past year get almost no coverage https://t.co/6gD8MzD6VU', 'sentiment': 'negative', 'polarity': -0.10555555555555557, 'date': datetime.datetime(2018, 5, 14, 20, 54, 12)}   - Date:  2018-05-14 20:54:12
# Tweet:  {'text': '@sokane1 @TalkTesla @Techmeme @timkhiggins Yes', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 14, 20, 15, 17)}   - Date:  2018-05-14 20:15:17
# Tweet:  {'text': '@TalkTesla @Techmeme @timkhiggins According to NHTSA, there was an automotive fatality every 86M miles in 2017 (~40,000 deaths). Tesla was every 320M miles. It’s not possible to be zero, but probability of fatality is much lower in a Tesla. We will be reporting updated safety numbers after each quarter.', 'sentiment': 'positive', 'polarity': 0.1, 'date': datetime.datetime(2018, 5, 14, 19, 40, 19)}   - Date:  2018-05-14 19:40:19
# Tweet:  {'text': '@Techmeme @timkhiggins This is false. Eyetracking rejected for being ineffective, not for cost. WSJ fails to mention that Tesla is safest car on road, which would make article ridiculous. Approx 4X better than avg.', 'sentiment': 'negative', 'polarity': -0.18333333333333335, 'date': datetime.datetime(2018, 5, 14, 19, 0, 17)}   - Date:  2018-05-14 19:00:17
# Tweet:  {'text': '@mayemusk Happy Mother’s Day Mom! Love you so much.', 'sentiment': 'positive', 'polarity': 0.5, 'date': datetime.datetime(2018, 5, 14, 0, 29, 10)}   - Date:  2018-05-14 00:29:10
# Tweet:  {'text': '@arstechnica Fair criticism, but we’re fixing it fast. Hackathon going on right now to fix 2 worst robot production chokepoints. Looks promising.', 'sentiment': 'positive', 'polarity': 0.0771428571428571, 'date': datetime.datetime(2018, 5, 14, 0, 27, 15)}   - Date:  2018-05-14 00:27:15
# Tweet:  {'text': 'RT @SpaceX: More photos from the first flight of Falcon 9 Block 5 → https://t.co/095WHWMtKp https://t.co/4gZsAc01Bg', 'sentiment': 'positive', 'polarity': 0.375, 'date': datetime.datetime(2018, 5, 14, 0, 18, 35)}   - Date:  2018-05-14 00:18:35
# Tweet:  {'text': 'Lovely story https://t.co/fIsvSIx3Uu', 'sentiment': 'positive', 'polarity': 0.5, 'date': datetime.datetime(2018, 5, 14, 0, 16, 33)}   - Date:  2018-05-14 00:16:33
# Tweet:  {'text': '@devrim_ogun @RitaJKing If someone is trying to control us through complicated sky patterns, they must really care. I would gladly obey their instructions, but I can’t figure them out.', 'sentiment': 'positive', 'polarity': 0.06666666666666667, 'date': datetime.datetime(2018, 5, 13, 1, 42, 15)}   - Date:  2018-05-13 01:42:15
# Tweet:  {'text': '@Everman SpaceX will prob build 30 to 40 rocket cores for ~300 missions over 5 years. Then BFR takes over &amp; Falcon retires. Goal of BFR is to enable anyone to move to moon, Mars &amp; eventually outer planets.', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 13, 0, 37, 15)}   - Date:  2018-05-13 00:37:15
# Tweet:  {'text': 'Good piece by Ars https://t.co/7C3X0TjUX9', 'sentiment': 'positive', 'polarity': 0.7, 'date': datetime.datetime(2018, 5, 13, 0, 29, 39)}   - Date:  2018-05-13 00:29:39
# Tweet:  {'text': '@RitaJKing Rate at which things are getting more bizarre appears to be increasing', 'sentiment': 'positive', 'polarity': 0.45, 'date': datetime.datetime(2018, 5, 12, 23, 42, 4)}   - Date:  2018-05-12 23:42:04
# Tweet:  {'text': '@DylanNeumann2 @Everman Exactly. Gasoline cars will be like steam engines — quaint, but not something you’d actually use to get around. Btw, I like steam engines &amp; trains in general.', 'sentiment': 'positive', 'polarity': 0.10000000000000002, 'date': datetime.datetime(2018, 5, 12, 23, 37, 43)}   - Date:  2018-05-12 23:37:43
# Tweet:  {'text': '@Everman Yeah, I heard this so many times. In the future, it will seem bizarre that we used to crash rockets into the ocean instead of reusing them.', 'sentiment': 'positive', 'polarity': 0.3, 'date': datetime.datetime(2018, 5, 12, 23, 33, 10)}   - Date:  2018-05-12 23:33:10
# Tweet:  {'text': 'RT @SpaceX: Falcon 9 Block 5 first stage has landed on the Of Course I Still Love You droneship. https://t.co/YHqdxIrc8b', 'sentiment': 'positive', 'polarity': 0.375, 'date': datetime.datetime(2018, 5, 12, 5, 53, 44)}   - Date:  2018-05-12 05:53:44
# Tweet:  {'text': '@boringcompany Yo', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 12, 2, 16, 9)}   - Date:  2018-05-12 02:16:09
# Tweet:  {'text': '@PodcastTeslas Will make that a setting', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 11, 22, 24, 30)}   - Date:  2018-05-11 22:24:30
# Tweet:  {'text': '@existentialcoms Fossil fuels subsidized at $10 million a minute, 24 hours a day, 7 days a week https://t.co/zAZOohjb4E', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 11, 22, 20, 42)}   - Date:  2018-05-11 22:20:42
# Tweet:  {'text': '@existentialcoms No use arguing with chimp. You’re blocked.', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 11, 22, 16, 52)}   - Date:  2018-05-11 22:16:52
# Tweet:  {'text': '@existentialcoms That article was pushed as propaganda to counter IMF study showing fossil fuel subsidies to be $5 trillion/year. Even if $4.9B was true, combined market cap of Tesla &amp; SpaceX is $80B. Where did the other $75B come from? Ass 🎩 …', 'sentiment': 'positive', 'polarity': 0.04166666666666666, 'date': datetime.datetime(2018, 5, 11, 22, 3, 57)}   - Date:  2018-05-11 22:03:57
# Tweet:  {'text': 'RT @SpaceX: Successful deployment of Bangabandhu Satellite-1 to geostationary transfer orbit confirmed. https://t.co/aX7kRQtBpZ', 'sentiment': 'positive', 'polarity': 0.575, 'date': datetime.datetime(2018, 5, 11, 21, 34, 35)}   - Date:  2018-05-11 21:34:35
# Tweet:  {'text': 'RT @thesheetztweetz: Look at the relief from @elonmusk on the @SpaceX livestream – you can tell how important this first #Block5 mission wa…', 'sentiment': 'positive', 'polarity': 0.325, 'date': datetime.datetime(2018, 5, 11, 21, 17, 21)}   - Date:  2018-05-11 21:17:21
# Tweet:  {'text': '@archangel_cap @existentialcoms I have publicly asked people (like you) not to invest. Go fund Ford or whatever  …', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 11, 20, 12, 7)}   - Date:  2018-05-11 20:12:07
# Tweet:  {'text': 'Launching in ~4 mins https://t.co/4vMvdEQAx7', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 11, 20, 9, 55)}   - Date:  2018-05-11 20:09:55
# Tweet:  {'text': '@DMC_Ryan @AnthonyFultz AWD &amp; white interior in July. Air suspension prob later. Note, that’s when we *start* making them. Can’t instantly fill all orders. Will take 6+ months to do so.', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 11, 19, 55, 22)}   - Date:  2018-05-11 19:55:22
# Tweet:  {'text': '@existentialcoms Our giant auto co competitors have much greater access to incentives than Tesla, which means Tesla has prospered in spite of govt subsidies, not because of them. Tesla mkt cap has *risen* over time as EV incentives declined. How strange …', 'sentiment': 'positive', 'polarity': 0.15, 'date': datetime.datetime(2018, 5, 11, 19, 52, 22)}   - Date:  2018-05-11 19:52:22
# Tweet:  {'text': '@AnthonyFultz @DMC_Ryan I love it too, but trying to keep config simple so as not to blow up the production ramp', 'sentiment': 'positive', 'polarity': 0.25, 'date': datetime.datetime(2018, 5, 11, 19, 21, 31)}   - Date:  2018-05-11 19:21:31
# Tweet:  {'text': '@DMC_Ryan Tesla will enable orders end of next week for dual motor AWD &amp; performance. Starting production of those in July. Air suspension prob next year.', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 11, 16, 40, 57)}   - Date:  2018-05-11 16:40:57
# Tweet:  {'text': 'RT @ElectrekCo: Tesla’s giant battery in Australia reduced grid service cost by\xa090% https://t.co/vzKgWm742S by @fredericlambert https://t.c…', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 11, 16, 27, 20)}   - Date:  2018-05-11 16:27:20
# Tweet:  {'text': '@nextspaceflight A cool thing about the design is that’s easy to incorporate branch loops to serve small to mid size cities without slowing down the main loop at all', 'sentiment': 'positive', 'polarity': 0.09074074074074073, 'date': datetime.datetime(2018, 5, 11, 2, 13, 24)}   - Date:  2018-05-11 02:13:24
# Tweet:  {'text': '@MissTrade Already started DC to NY route. \nHopefully start LA to SF next year. That will be true @Hyperloop w pressurized pods in near vacuum tunnels &amp; faster than jetliner.', 'sentiment': 'positive', 'polarity': 0.11041666666666665, 'date': datetime.datetime(2018, 5, 11, 2, 7, 14)}   - Date:  2018-05-11 02:07:14
# Tweet:  {'text': 'First Boring Company tunnel under LA almost done! Pending final… https://t.co/oWHlwOgCJE', 'sentiment': 'negative', 'polarity': -0.25, 'date': datetime.datetime(2018, 5, 11, 2, 2, 4)}   - Date:  2018-05-11 02:02:04
# Tweet:  {'text': '@isayeter Towards end of next year. Btw, planning to launch Tesla in Turkey later this year. Love your country &amp; will be there in person for the launch.', 'sentiment': 'positive', 'polarity': 0.16666666666666666, 'date': datetime.datetime(2018, 5, 11, 0, 42, 7)}   - Date:  2018-05-11 00:42:07
# Tweet:  {'text': '@tammyharrington @Josh1C This will work on entire S &amp; X fleet, even first production units. Cool thing about software upgrades is that we can keep making your car better long after you bought it.', 'sentiment': 'positive', 'polarity': 0.21000000000000002, 'date': datetime.datetime(2018, 5, 11, 0, 39, 58)}   - Date:  2018-05-11 00:39:58
# Tweet:  {'text': 'RT @SpaceX: Standing down today due to a standard ground system auto abort at T-1 min. Rocket and payload are in good health—teams are work…', 'sentiment': 'positive', 'polarity': 0.1048611111111111, 'date': datetime.datetime(2018, 5, 11, 0, 34, 24)}   - Date:  2018-05-11 00:34:24
# Tweet:  {'text': 'RT @SpaceX: Falcon 9 Block 5 and Bangabandhu Satellite-1 went vertical on Pad 39A in Florida this morning. Now targeting liftoff at 4:42 p.…', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 10, 17, 46, 45)}   - Date:  2018-05-10 17:46:45
# Tweet:  {'text': '@Josh1C All X &amp; S will soon work with no key if your phone pairs w Bluetooth, signal strength is high &amp; you enable feature', 'sentiment': 'positive', 'polarity': 0.08, 'date': datetime.datetime(2018, 5, 10, 11, 11, 17)}   - Date:  2018-05-10 11:11:17
# Tweet:  {'text': '@Josh1C Yeah, we will add that as a feature', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 10, 11, 7, 44)}   - Date:  2018-05-10 11:07:44
# Tweet:  {'text': '@simona_moise @MacTechGenius @teslanomicsco @Wayfair @TeslaClubSweden !! Unnecessary characters. Will change.', 'sentiment': 'negative', 'polarity': -0.4, 'date': datetime.datetime(2018, 5, 10, 11, 6, 16)}   - Date:  2018-05-10 11:06:16
# Tweet:  {'text': '@MacTechGenius @teslanomicsco @Wayfair @TeslaClubSweden I wrote that masterpiece myself in HTML 1.0', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 10, 10, 18, 5)}   - Date:  2018-05-10 10:18:05
# Tweet:  {'text': '@teslanomicsco @Wayfair @TeslaClubSweden Wow, thanks for the couch! I will match the donation from my foundation.', 'sentiment': 'positive', 'polarity': 0.15000000000000002, 'date': datetime.datetime(2018, 5, 10, 6, 45, 13)}   - Date:  2018-05-10 06:45:13
# Tweet:  {'text': '@alyankovic @Grimezsz My a capella cover of Amish Paradise is irresistible https://t.co/mBo6aJV42O', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 10, 6, 15, 23)}   - Date:  2018-05-10 06:15:23
# Tweet:  {'text': 'RT @Tesla: Wild horses in winter at Gigafactory 1 https://t.co/bbGp9NwBbq', 'sentiment': 'positive', 'polarity': 0.1, 'date': datetime.datetime(2018, 5, 10, 3, 6, 13)}   - Date:  2018-05-10 03:06:13
# Tweet:  {'text': 'Tesla quarterly all-hands video. Love the shot of wild horses &amp; Giga in winter https://t.co/ZGZbpSFhus', 'sentiment': 'positive', 'polarity': 0.3, 'date': datetime.datetime(2018, 5, 10, 1, 0, 56)}   - Date:  2018-05-10 01:00:56
# Tweet:  {'text': '@freebasecatnip So rococo', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 9, 23, 31, 38)}   - Date:  2018-05-09 23:31:38
# Tweet:  {'text': 'RT @Tesla: 50 million Americans say their next vehicle will be electric\nhttps://t.co/z6rRoWKFzc', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 9, 21, 57, 32)}   - Date:  2018-05-09 21:57:32
# Tweet:  {'text': '@ablack82 Definitely not a logo of any kind', 'sentiment': 'positive', 'polarity': 0.3, 'date': datetime.datetime(2018, 5, 9, 20, 7, 59)}   - Date:  2018-05-09 20:07:59
# Tweet:  {'text': '@MeriamMagic @CatherineUllo Stole it', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 9, 18, 16, 38)}   - Date:  2018-05-09 18:16:38
# Tweet:  {'text': '@NannySoleil @CatherineUllo We sketched concept together &amp; worked w a trusted team to make it', 'sentiment': 'neutral', 'polarity': 0.0, 'date': datetime.datetime(2018, 5, 9, 17, 39, 5)}   - Date:  2018-05-09 17:39:05
# Tweet:  {'text': '@CatherineUllo Glass corset hand-painted in perspective in color of bone. Every detail tells a story. Spiked choker machined from a single piece of forged metal. Crown of Vantablack.', 'sentiment': 'negative', 'polarity': -0.07142857142857142, 'date': datetime.datetime(2018, 5, 9, 17, 34, 40)}   - Date:  2018-05-09 17:34:40
# Positive tweets:  1532 ( 47.21109399075501 %)
# Neutral tweets:  1291 ( 39.78428351309707 %)
# Negative tweets:  422 ( 13.004622496147919 %)
# C:\Users\Jack\Anaconda3\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
